# %% [markdown]
# ## Institutions Schema

# %%
import jsonlines

# %% [markdown]
# ## Sample (n=10)

# %% [markdown]
# zcat updated_date=2025-11-11/part_000.gz | shuf -n10

# %%
data = []

with jsonlines.open('schemas/institutions_schema/schema_institutions_2025-11-11.jsonl') as file:
    data = list(file.iter())

# %%
sorted(data[0].keys())
# Out:
# ['associated_institutions',
#  'cited_by_count',
#  'country_code',
#  'counts_by_year',
#  'created_date',
#  'display_name',
#  'display_name_acronyms',
#  'display_name_alternatives',
#  'geo',
#  'homepage_url',
#  'id',
#  'ids',
#  'image_thumbnail_url',
#  'image_url',
#  'is_super_system',
#  'lineage',
#  'repositories',
#  'roles',
#  'ror',
#  'summary_stats',
#  'topic_share',
#  'topics',
#  'type',
#  'type_id',
#  'updated_date',
#  'wiki_page',
#  'wikidata_id',
#  'works_api_url',
#  'works_count']
