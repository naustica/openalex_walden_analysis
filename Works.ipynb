# %% [markdown]
# ## Works Schema

# %%
import jsonlines

# %% [markdown]
# ## Sample (n=10)

# %% [markdown]
# zcat updated_date=2025-11-11/part_0000.gz | shuf -n10

# %%
data = []

with jsonlines.open('schemas/works_schema/works_schema_2025-11-11.jsonl') as file:
    data = list(file.iter())

# %%
sorted(data[0].keys())
# Out:
# ['apc_list',
#  'authors_count',
#  'authorships',
#  'awards',
#  'biblio',
#  'cited_by_api_url',
#  'cited_by_count',
#  'concepts',
#  'corresponding_author_ids',
#  'corresponding_institution_ids',
#  'countries_distinct_count',
#  'counts_by_year',
#  'created_date',
#  'display_name',
#  'doi',
#  'funders',
#  'fwci',
#  'grants',
#  'has_abstract',
#  'has_content',
#  'id',
#  'ids',
#  'indexed_in',
#  'indexed_in_crossref',
#  'institutions',
#  'institutions_distinct_count',
#  'is_paratext',
#  'is_retracted',
#  'is_xpac',
#  'keywords',
#  'language',
#  'locations',
#  'locations_count',
#  'mesh',
#  'open_access',
#  'primary_location',
#  'publication_date',
#  'publication_year',
#  'publisher',
#  'referenced_works',
#  'referenced_works_count',
#  'related_works',
#  'sustainable_development_goals',
#  'title',
#  'topics',
#  'topics_key',
#  'type']

# %%
for i in range(9):
    print(set(sorted(data[i].keys())) - set(sorted(data[i+1].keys())))
# Out:
# {'apc_list'}
# set()
# {'abstract_inverted_index', 'fulltext', 'language', 'primary_topic', 'citation_normalized_percentile', 'cited_by_percentile_year'}
# set()
# set()
# set()
# set()
# {'primary_topic', 'citation_normalized_percentile', 'cited_by_percentile_year'}
# {'apc_list', 'apc_paid'}

# %%
sorted(data[i]['primary_location'].keys())
# Out:
# ['apc_prices',
#  'apc_usd',
#  'host_type',
#  'is_accepted',
#  'is_oa',
#  'is_published',
#  'is_unpaywall_record',
#  'landing_page_url',
#  'license',
#  'license_id',
#  'location_type',
#  'native_id',
#  'oa_status',
#  'provenance',
#  'raw_source_name',
#  'raw_type',
#  'sort_score',
#  'source',
#  'updated',
#  'url_sort_score',
#  'version']

# %%
for i in range(9):
    print(set(sorted(data[i]['primary_location'].keys())) - set(sorted(data[i+1]['primary_location'].keys())))
# Out:
# {'apc_prices', 'version', 'apc_usd', 'is_published', 'raw_source_name', 'is_accepted'}
# set()
# {'raw_source_name', 'host_type', 'grobid_s3_id', 'source'}
# {'pdf_s3_id', 'pdf_url'}
# {'version', 'pmh_id', 'license', 'license_id', 'endpoint_id', 'is_published', 'is_accepted'}
# set()
# set()
# set()
# {'apc_prices', 'version', 'license', 'license_id', 'apc_usd', 'is_published', 'raw_source_name', 'is_accepted'}

# %%
sorted(data[i]['primary_location']['source'].keys())
# Out:
# ['display_name',
#  'host_organization',
#  'host_organization_lineage',
#  'host_organization_lineage_names',
#  'host_organization_name',
#  'id',
#  'is_core',
#  'is_in_doaj',
#  'is_oa',
#  'issn',
#  'issn_l',
#  'raw_type',
#  'type']

# %%
for i in range(9):
    try:
        print(set(sorted(data[i]['primary_location']['source'].keys())) - set(sorted(data[i+1]['primary_location']['source'].keys())))
    except:
        pass
# Out:
# {'host_organization_name', 'host_organization', 'issn_l'}
# set()
# {'host_organization', 'host_organization_name'}
# set()
# set()
# set()
# {'host_organization_name', 'host_organization', 'issn_l'}

# %%
sorted(data[0]['authorships'][0].keys())
# Out:
# ['affiliations',
#  'author',
#  'author_position',
#  'countries',
#  'institutions',
#  'is_corresponding',
#  'raw_affiliation_strings',
#  'raw_author_name']

# %%
for i in range(9):
    print(set(sorted(data[i]['authorships'][0].keys())) - set(sorted(data[i+1]['authorships'][0].keys())))
# Out:
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()

# %%
sorted(data[0]['ids'].keys())
# Out:
# ['doi', 'openalex']

# %%
for i in range(9):
    print(set(sorted(data[i]['ids'].keys())) - set(sorted(data[i+1]['ids'].keys())))
# Out:
# set()
# set()
# {'mag'}
# {'doi'}
# set()
# set()
# set()
# set()
# set()

# %% [markdown]
# ## Random Sample (n=200)

# %% [markdown]
# zcat updated_date=2025-11-11/part_0000.gz | shuf -n200 | jq -r '[paths|map(.|tostring)|join(".")]' | sort -u

# %% [markdown]
# abstract_inverted_index
#
# apc_list
#
# apc_list.currency
#
# apc_list.value
#
# apc_list.value_usd
#
# apc_paid
#
# apc_paid.currency
#
# apc_paid.value
#
# apc_paid.value_usd
#
# authors_count
#
# authorships
#
# authorships.affiliations
#
# authorships.affiliations.institution_ids
#
# authorships.affiliations.raw_affiliation_string
#
# authorships.author
#
# authorships.author.display_name
#
# authorships.author.id
#
# authorships.author.orcid
#
# authorships.author_position
#
# authorships.countries
#
# authorships.institutions
#
# authorships.institutions.country_code
#
# authorships.institutions.display_name
#
# authorships.institutions.id
#
# authorships.institutions.lineage
#
# authorships.institutions.ror
#
# authorships.institutions.type
#
# authorships.institutions.type_list
#
# authorships.is_corresponding
#
# authorships.raw_author_name
#
# awards
#
# best_oa_location
#
# best_oa_location.apc_prices
#
# best_oa_location.apc_prices
#
# best_oa_location.apc_prices.currency
#
# best_oa_location.apc_prices.price
#
# best_oa_location.apc_usd
#
# best_oa_location.endpoint_id
#
# best_oa_location.grobid_s3_id
#
# best_oa_location.host_type
#
# best_oa_location.is_accepted
#
# best_oa_location.is_oa
#
# best_oa_location.is_published
#
# best_oa_location.is_unpaywall_record
#
# best_oa_location.landing_page_url
#
# best_oa_location.license
#
# best_oa_location.license_id
#
# best_oa_location.location_type
#
# best_oa_location.native_id
#
# best_oa_location.oa_status
#
# best_oa_location.pdf_s3_id
#
# best_oa_location.pdf_url
#
# best_oa_location.pmh_id
#
# best_oa_location.provenance
#
# best_oa_location.raw_source_name
#
# best_oa_location.raw_type
#
# best_oa_location.sort_score
#
# best_oa_location.source
#
# best_oa_location.source.display_name
#
# best_oa_location.source.host_organization
#
# best_oa_location.source.host_organization_lineage
#
# best_oa_location.source.host_organization_lineage_names
#
# best_oa_location.source.host_organization_name
#
# best_oa_location.source.id
#
# best_oa_location.source.is_core
#
# best_oa_location.source.is_in_doaj
#
# best_oa_location.source.is_oa
#
# best_oa_location.source.issn
#
# best_oa_location.source.issn
#
# best_oa_location.source.issn_l
#
# best_oa_location.source.raw_type
#
# best_oa_location.source.type
#
# best_oa_location.updated
#
# best_oa_location.url_sort_score
#
# best_oa_location.version
#
# biblio
#
# biblio.first_page
#
# biblio.issue
#
# biblio.last_page
#
# biblio.volume
#
# citation_normalized_percentile
#
# citation_normalized_percentile.is_in_top_10_percent
#
# citation_normalized_percentile.is_in_top_1_percent
#
# citation_normalized_percentile.value
#
# cited_by_api_url
#
# cited_by_count
#
# cited_by_percentile_year
#
# cited_by_percentile_year.max
#
# cited_by_percentile_year.min
#
# concepts
#
# corresponding_author_ids
#
# corresponding_institution_ids
#
# countries_distinct_count
#
# counts_by_year
#
# counts_by_year.cited_by_count
#
# counts_by_year.year
#
# created_date
#
# display_name
#
# doi
#
# fulltext
#
# funders
#
# funders.display_name
#
# funders.id
#
# funders.ror
#
# fwci
#
# grants
#
# grants.award_id
#
# grants.funder
#
# grants.funder_display_name
#
# has_abstract
#
# has_content
#
# has_content.grobid_xml
#
# has_content.pdf
#
# id
#
# ids
#
# ids.doi
#
# ids.mag
#
# ids.openalex
#
# ids.pmid
#
# indexed_in
#
# indexed_in_crossref
#
# institutions
#
# institutions_distinct_count
#
# is_paratext
#
# is_retracted
#
# is_xpac
#
# keywords
#
# language
#
# locations
#
# locations.is_oa
#
# locations.is_published
#
# locations.landing_page_url
#
# locations.license
#
# locations.license_id
#
# locations.native_id
#
# locations.pdf_url
#
# locations.provenance
#
# locations.raw_source_name
#
# locations.source
#
# locations.source.display_name
#
# locations.source.host_organization
#
# locations.source.host_organization_lineage
#
# locations.source.host_organization_lineage
#
# locations.source.host_organization_lineage_names
#
# locations.source.host_organization_name
#
# locations.source.id
#
# locations.source.is_core
#
# locations.source.is_in_doaj
#
# locations.source.is_oa
#
# locations.source.issn
#
# locations.source.issn_l
#
# locations.source.raw_type
#
# locations.source.type
#
# locations_count
#
# mesh
#
# mesh.descriptor_name
#
# mesh.descriptor_ui
#
# mesh.is_major_topic
#
# open_access
#
# open_access.any_repository_has_fulltext
#
# open_access.is_oa
#
# open_access.oa_status
#
# open_access.oa_url
#
# primary_location
#
# primary_location.apc_prices
#
# primary_location.apc_prices.currency
#
# primary_location.apc_prices.price
#
# primary_location.apc_usd
#
# primary_location.endpoint_id
#
# primary_location.grobid_s3_id
#
# primary_location.host_type
#
# primary_location.is_accepted
#
# primary_location.is_oa
#
# primary_location.is_published
#
# primary_location.is_unpaywall_record
#
# primary_location.landing_page_url
#
# primary_location.license
#
# primary_location.license_id
#
# primary_location.location_type
#
# primary_location.native_id
#
# primary_location.oa_status
#
# primary_location.pdf_s3_id
#
# primary_location.pdf_url
#
# primary_location.pmh_id
#
# primary_location.provenance
#
# primary_location.raw_source_name
#
# primary_location.raw_type
#
# primary_location.sort_score
#
# primary_location.source
#
# primary_location.source.display_name
#
# primary_location.source.host_organization
#
# primary_location.source.host_organization_lineage
#
# primary_location.source.host_organization_lineage_names
#
# primary_location.source.host_organization_name
#
# primary_location.source.id
#
# primary_location.source.is_core
#
# primary_location.source.is_in_doaj
#
# primary_location.source.is_oa
#
# primary_location.source.issn
#
# primary_location.source.issn_l
#
# primary_location.source.raw_type
#
# primary_location.source.type
#
# primary_location.updated
#
# primary_location.url_sort_score
#
# primary_location.version
#
# primary_topic
#
# primary_topic.display_name
#
# primary_topic.domain
#
# primary_topic.domain.display_name
#
# primary_topic.domain.id
#
# primary_topic.field
#
# primary_topic.field.display_name
#
# primary_topic.field.id
#
# primary_topic.id
#
# primary_topic.score
#
# primary_topic.subfield
#
# primary_topic.subfield.display_name
#
# primary_topic.subfield.id
#
# publication_date
#
# publication_year
#
# publisher
#
# referenced_works
#
# referenced_works_count
#
# related_works
#
# sustainable_development_goals
#
# sustainable_development_goals.display_name
#
# sustainable_development_goals.id
#
# sustainable_development_goals.score
#
# title
#
# topics
#
# topics_key
#
# type
