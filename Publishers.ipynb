# %% [markdown]
# ## Publishers Schema

# %%
import jsonlines

# %% [markdown]
# ## Sample (n=10)

# %% [markdown]
# zcat updated_date=2025-07-02/part_000.gz | shuf -n10

# %%
data = []

with jsonlines.open('schemas/publishers_schema/publishers_schema_2025-07-02.jsonl') as file:
    data = list(file.iter())

# %%
sorted(data[0].keys())
# Out:
# ['alternate_titles',
#  'country_code',
#  'country_codes',
#  'country_name',
#  'created_date',
#  'display_name',
#  'hierarchy_level',
#  'homepage_url',
#  'id',
#  'ids',
#  'image_thumbnail_url',
#  'image_url',
#  'is_approved',
#  'merge_into_date',
#  'merge_into_id',
#  'parent_publisher',
#  'parent_publisher_wikidata',
#  'ror_id',
#  'updated_date',
#  'wikidata_id']
