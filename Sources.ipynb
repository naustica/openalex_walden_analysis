# %% [markdown]
# ## Sources Schema

# %%
import jsonlines

# %% [markdown]
# ## Sample (n=10)

# %% [markdown]
# zcat updated_date=2025-11-02/part_000.gz | shuf -n10

# %%
data = []

with jsonlines.open('schemas/sources_schema/sources_schema_2025-11-02.jsonl') as file:
    data = list(file.iter())

# %%
sorted(data[0].keys())
# Out:
# ['alternate_titles',
#  'apc_prices',
#  'apc_usd',
#  'cited_by_count',
#  'country_code',
#  'counts_by_year',
#  'created_date',
#  'display_name',
#  'first_publication_year',
#  'homepage_url',
#  'host_organization',
#  'host_organization_lineage',
#  'host_organization_name',
#  'id',
#  'ids',
#  'is_core',
#  'is_high_oa_rate',
#  'is_high_oa_rate_since_year',
#  'is_in_doaj',
#  'is_in_doaj_since_year',
#  'is_in_scielo',
#  'is_oa',
#  'is_ojs',
#  'issn',
#  'issn_l',
#  'last_publication_year',
#  'oa_flip_year',
#  'oa_works_count',
#  'societies',
#  'summary_stats',
#  'topic_share',
#  'topics',
#  'type',
#  'updated_date',
#  'works_api_url',
#  'works_count']
